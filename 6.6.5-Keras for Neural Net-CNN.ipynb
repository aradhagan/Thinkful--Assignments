# %%
# !pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 44kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.8.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (3.7.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.1.7)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (0.33.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu) (1.16.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu) (0.15.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu) (2.8.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.14.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import tensorflow as tf
import keras
tf.__version__
# Out:
# Using TensorFlow backend.
# '1.14.0'

# %%
# Import the dataset
from keras.datasets import cifar10

# Import various componenets for model building
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from keras.layers import LSTM, Input, TimeDistributed
from keras.models import Model
from keras.optimizers import RMSprop

# Import the backend
from keras import backend as K

# %%
# Loading the data set into X and Y splits 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
#@title
x_train_sample = x_train[0:50000, :, :, :]
y_train_sample = y_train[0:50000, :]
x_test_sample = x_test[0:10000, :, :, :]
y_test_sample = y_test[0:10000, :]

# %%
print ('x_train shape', x_train_sample.shape)
print ('y_train shape', y_train_sample.shape)
print ('x_test shape', x_test_sample.shape)
print ('y_test shape', y_test_sample.shape)
# Out:
# x_train shape (50000, 32, 32, 3)
# y_train shape (50000, 1)
# x_test shape (10000, 32, 32, 3)
# y_test shape (10000, 1)

# %%
# Viewing some sample images in the dataset

sns.set(rc={'figure.figsize':(10,7)}, style='dark', color_codes=True)
label_dict={0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog',
            7: 'horse', 8: 'ship', 9: 'truck'}

def show_images(X):
    plt.figure(1)
    k = 0
    for i in range(0,4):
        for j in range(0,4):
            plt.subplot2grid((4,4),(i,j))
            plt.imshow(X[k])
            plt.title(label_dict[y_test[k][0]], fontsize=15)
            plt.tight_layout()
            k+=1
    # show the plot
    plt.show()
    
show_images(x_test[0:16])
plt.show()

# %% [markdown]
# # Implementation 1: Multi Layer Perceptron

# %%
# Change shape 
# Note that our images are 32*32 pixels, so in reshaping to arrays we want
# 60,000 arrays of length 1024, times three for each image
x_train_sample = x_train_sample.reshape(50000, 3072)
x_test_sample = x_test_sample.reshape(10000, 3072)

# %%
# Convert to float32 for type consistency
x_train_sample = x_train_sample.astype('float32')
x_test_sample = x_test_sample.astype('float32')

# Normalize values to 1 from 0 to 255 (256 values of pixels)
x_train_sample /= 255
x_test_sample /= 255

# Print sample sizes
print(x_train_sample.shape[0], 'train samples')
print(y_test_sample.shape[0], 'test samples')

# Convert class vectors to binary class matrices
# So instead of one column with 10 values, create 10 binary columns
y_train_sample = keras.utils.to_categorical(y_train_sample, 10)
y_test_sample = keras.utils.to_categorical(y_test_sample, 10)
# Out:
# 50000 train samples
# 10000 test samples

# %%
x_train_sample.shape[1:]
# Out:
# (3072,)

# %%
# Start with a simple sequential model
model = Sequential()

# Add dense layers to create a fully connected MLP
# Note that we specify an input shape for the first layer, but only the first layer.
# Relu is the activation function used
model.add(Dense(128, activation='relu', input_shape=x_train_sample.shape[1:]))
# Dropout layers remove features and fight overfitting
model.add(Dropout(0.1))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.1))
# End with a number of units equal to the number of classes we have for our outcome
model.add(Dense(10, activation='softmax'))

model.summary()

# Compile the model to put it all together.
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0628 21:25:26.677930 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0628 21:25:26.694556 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0628 21:25:26.697479 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0628 21:25:26.715102 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0628 21:25:26.723605 139694989375360 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0628 21:25:26.823384 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0628 21:25:26.834343 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               393344
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 418,762
# Trainable params: 418,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train_sample, y_train_sample,
                    batch_size=64,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test_sample, y_test_sample))
score = model.evaluate(x_test_sample, y_test_sample, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# W0628 21:25:26.952344 139694989375360 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 7s 131us/step - loss: 2.0110 - acc: 0.2650 - val_loss: 1.9193 - val_acc: 0.2854
# Epoch 2/10
# 50000/50000 [==============================] - 4s 75us/step - loss: 1.8472 - acc: 0.3324 - val_loss: 1.7663 - val_acc: 0.3577
# Epoch 3/10
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.7878 - acc: 0.3563 - val_loss: 1.8389 - val_acc: 0.3352
# Epoch 4/10
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.7469 - acc: 0.3722 - val_loss: 1.6846 - val_acc: 0.3862
# Epoch 5/10
# 50000/50000 [==============================] - 4s 70us/step - loss: 1.7192 - acc: 0.3839 - val_loss: 1.7329 - val_acc: 0.3848
# Epoch 6/10
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.6949 - acc: 0.3914 - val_loss: 1.7366 - val_acc: 0.3580
# Epoch 7/10
# 50000/50000 [==============================] - 4s 72us/step - loss: 1.6834 - acc: 0.3964 - val_loss: 1.6367 - val_acc: 0.4052
# Epoch 8/10
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6689 - acc: 0.4028 - val_loss: 1.6199 - val_acc: 0.4158
# Epoch 9/10
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6540 - acc: 0.4058 - val_loss: 1.7886 - val_acc: 0.3496
# Epoch 10/10
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.6444 - acc: 0.4104 - val_loss: 1.6039 - val_acc: 0.4223
# Test loss: 1.6038808601379395
# Test accuracy: 0.4223

# %% [markdown]
# With MLP accuracy was only around 40% of course it is the simplest of the neural netwoprks.  The computational time was around 38secs for training with 10 epochs. The computational time was low and the accuracy was also low.

# %%
y_pred = model.predict_classes(x_test_sample)
y_pred = y_pred.reshape(10000,1)

# %%
# Viewing wrong predictions with the data....compared to the original labels as shown before...

sns.set(rc={'figure.figsize':(10,7)}, style='dark', color_codes=True)
label_dict={0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog',
            7: 'horse', 8: 'ship', 9: 'truck'}

def show_images(X):
    plt.figure(1)
    k = 0
    for i in range(0,4):
        for j in range(0,4):
            plt.subplot2grid((4,4),(i,j))
            plt.imshow(X[k])
            plt.title(label_dict[y_pred[k][0]], fontsize=15)
            plt.tight_layout()
            k+=1
    # show the plot
    plt.show()
    
show_images(x_test[0:16])
plt.show()

# %%
label_dict # Labels in model
# Out:
# {0: 'airplane',
#  1: 'automobile',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %% [markdown]
# # Implementation 2:  Convolutional Neural Networks

# %%
# Loading the data set into X and Y splits 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train.shape[1:]
# Out:
# (32, 32, 3)

# %%
# input image dimensions, from our data
img_rows, img_cols = 32, 32
num_classes = 10

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# Building the Model
model = Sequential()
# First convolutional layer, note the specification of shape
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=x_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
model.fit(x_train, y_train,
          batch_size=128,
          epochs=10,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# W0628 21:26:11.770878 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               1605760
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,626,442
# Trainable params: 1,626,442
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 9s 189us/step - loss: 1.7706 - acc: 0.3639 - val_loss: 1.3707 - val_acc: 0.5164
# Epoch 2/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.2762 - acc: 0.5481 - val_loss: 1.1261 - val_acc: 0.6045
# Epoch 3/10
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.0689 - acc: 0.6242 - val_loss: 0.9876 - val_acc: 0.6526
# Epoch 4/10
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.9393 - acc: 0.6720 - val_loss: 0.9572 - val_acc: 0.6633
# Epoch 5/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.8371 - acc: 0.7081 - val_loss: 0.9041 - val_acc: 0.6901
# Epoch 6/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7422 - acc: 0.7407 - val_loss: 0.9013 - val_acc: 0.6891
# Epoch 7/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.6550 - acc: 0.7694 - val_loss: 0.8824 - val_acc: 0.7022
# Epoch 8/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.5721 - acc: 0.7984 - val_loss: 0.8805 - val_acc: 0.7036
# Epoch 9/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.5002 - acc: 0.8251 - val_loss: 0.9960 - val_acc: 0.6861
# Epoch 10/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.4370 - acc: 0.8465 - val_loss: 0.9327 - val_acc: 0.7064
# Test loss: 0.9327186017036438
# Test accuracy: 0.7064

# %% [markdown]
# The computational time was around  63 secs for training with 10 epochs. The computational time was not that high compared to MLP and could achieve a 70% accuracy. Given the tradeoff that we are losing time and its more complex, I would still go with CNN since the accuracy is very high compared to 40%.

# %% [markdown]
# # Implementation 3:  Convolutional Neural Networks wtih additional Convl 2D layer and pooling layer

# %%
# Building the Model
model = Sequential()
# First convolutional layer, note the specification of shape
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=x_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.summary()
model.fit(x_train, y_train,
          batch_size=128,
          epochs=10,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 352,650
# Trainable params: 352,650
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 7s 136us/step - loss: 1.7919 - acc: 0.3523 - val_loss: 1.3594 - val_acc: 0.5276
# Epoch 2/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.2870 - acc: 0.5446 - val_loss: 1.0992 - val_acc: 0.6176
# Epoch 3/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.0661 - acc: 0.6289 - val_loss: 1.0091 - val_acc: 0.6479
# Epoch 4/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.9270 - acc: 0.6774 - val_loss: 0.9461 - val_acc: 0.6740
# Epoch 5/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.8243 - acc: 0.7124 - val_loss: 0.8607 - val_acc: 0.7036
# Epoch 6/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.7450 - acc: 0.7403 - val_loss: 0.8661 - val_acc: 0.7057
# Epoch 7/10
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.6752 - acc: 0.7642 - val_loss: 0.8015 - val_acc: 0.7309
# Epoch 8/10
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.6160 - acc: 0.7835 - val_loss: 0.7788 - val_acc: 0.7406
# Epoch 9/10
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.5601 - acc: 0.8044 - val_loss: 0.7781 - val_acc: 0.7368
# Epoch 10/10
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.5152 - acc: 0.8201 - val_loss: 0.8105 - val_acc: 0.7384
# Test loss: 0.8105170508384705
# Test accuracy: 0.7384

# %% [markdown]
# The computational time was around  60  secs for training with 10 epochs. The computational time was almost similar and could achieve a 72% accuracy. Here there is not much tradeoff since the times are almost similar I like the implementation 3,  model with hgiher percentage of 72% compared to 70%.

# %% [markdown]
# # Implementation 4:  Convolutional Neural Networks wtih different number of neurons and parameters

# %%
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization

# Building the Model
model = Sequential()
# First convolutional layer, note the specification of shape
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=x_train.shape[1:], padding='same'))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))



model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))




model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])
model.summary()
model.fit(x_train, y_train,
          batch_size=128,
          epochs=10,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 356,810
# Trainable params: 356,810
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 5s 107us/step - loss: 1.7596 - acc: 0.3644 - val_loss: 1.5251 - val_acc: 0.4432
# Epoch 2/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.3611 - acc: 0.5132 - val_loss: 1.1383 - val_acc: 0.5960
# Epoch 3/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.1809 - acc: 0.5811 - val_loss: 1.0567 - val_acc: 0.6261
# Epoch 4/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.0569 - acc: 0.6289 - val_loss: 0.9503 - val_acc: 0.6615
# Epoch 5/10
# 50000/50000 [==============================] - 4s 88us/step - loss: 0.9766 - acc: 0.6570 - val_loss: 0.9562 - val_acc: 0.6616
# Epoch 6/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.9072 - acc: 0.6802 - val_loss: 0.8679 - val_acc: 0.7010
# Epoch 7/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.8526 - acc: 0.7011 - val_loss: 0.7786 - val_acc: 0.7283
# Epoch 8/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.8036 - acc: 0.7179 - val_loss: 0.8552 - val_acc: 0.7076
# Epoch 9/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7679 - acc: 0.7328 - val_loss: 0.8370 - val_acc: 0.7147
# Epoch 10/10
# 50000/50000 [==============================] - 4s 89us/step - loss: 0.7329 - acc: 0.7439 - val_loss: 0.7289 - val_acc: 0.7464
# Test loss: 0.7288535843849182
# Test accuracy: 0.7464

# %% [markdown]
# The computational time was around  41  secs for training with 10 epochs. The computational time is much lower compared to previous models. And could achieve a 75% accuracy, higher than all models above. Here it is not touch to decide since the time is less and also accuracy is hgih.  I like the implementation 4,  model with hgiher percentage of 76% compared to 72%.

# %% [markdown]
# # Implementation 5:  Convolutional Neural Networks with Batch Normalization

# %%
from keras.layers import BatchNormalization

# Building the Model
model = Sequential()
# First convolutional layer, note the specification of shape
model.add(Conv2D(32, padding='same',kernel_size=(3, 3),
                 activation='relu',
                 input_shape=x_train.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))



model.add(Conv2D(128, (3, 3),padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))


model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.RMSprop(lr=0.001,decay=1e-6),
              metrics=['accuracy'])
model.summary()
model.fit(x_train, y_train,
          batch_size=128,
          epochs=100,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# W0628 21:29:08.087412 139694989375360 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 357,706
# Trainable params: 357,258
# Non-trainable params: 448
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.6055 - acc: 0.4471 - val_loss: 1.4183 - val_acc: 0.5289
# Epoch 2/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 1.1686 - acc: 0.5883 - val_loss: 1.0809 - val_acc: 0.6285
# Epoch 3/100
# 50000/50000 [==============================] - 6s 114us/step - loss: 1.0057 - acc: 0.6487 - val_loss: 1.2053 - val_acc: 0.5723
# Epoch 4/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.9171 - acc: 0.6808 - val_loss: 0.8981 - val_acc: 0.6913
# Epoch 5/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.8385 - acc: 0.7100 - val_loss: 1.3203 - val_acc: 0.6166
# Epoch 6/100
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.7866 - acc: 0.7258 - val_loss: 1.3344 - val_acc: 0.5863
# Epoch 7/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.7387 - acc: 0.7448 - val_loss: 0.9672 - val_acc: 0.6869
# Epoch 8/100
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.7036 - acc: 0.7564 - val_loss: 0.8814 - val_acc: 0.7205
# Epoch 9/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.6719 - acc: 0.7674 - val_loss: 0.8357 - val_acc: 0.7294
# Epoch 10/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.6432 - acc: 0.7766 - val_loss: 0.8616 - val_acc: 0.7212
# Epoch 11/100
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.6177 - acc: 0.7878 - val_loss: 0.7187 - val_acc: 0.7650
# Epoch 12/100
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.5969 - acc: 0.7940 - val_loss: 0.6677 - val_acc: 0.7798
# Epoch 13/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.5805 - acc: 0.7985 - val_loss: 0.9456 - val_acc: 0.7333
# Epoch 14/100
# 50000/50000 [==============================] - 6s 117us/step - loss: 0.5639 - acc: 0.8035 - val_loss: 0.8942 - val_acc: 0.7317
# Epoch 15/100
# 50000/50000 [==============================] - 6s 119us/step - loss: 0.5504 - acc: 0.8093 - val_loss: 0.7053 - val_acc: 0.7733
# Epoch 16/100
# 50000/50000 [==============================] - 6s 116us/step - loss: 0.5346 - acc: 0.8136 - val_loss: 0.8196 - val_acc: 0.7450
# Epoch 17/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.5166 - acc: 0.8199 - val_loss: 0.8462 - val_acc: 0.7564
# Epoch 18/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.5008 - acc: 0.8267 - val_loss: 0.8009 - val_acc: 0.7672
# Epoch 19/100
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.4858 - acc: 0.8325 - val_loss: 0.7466 - val_acc: 0.7584
# Epoch 20/100
# 50000/50000 [==============================] - 6s 114us/step - loss: 0.4780 - acc: 0.8356 - val_loss: 0.7292 - val_acc: 0.7772
# Epoch 21/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.4723 - acc: 0.8365 - val_loss: 1.1309 - val_acc: 0.7159
# Epoch 22/100
# 50000/50000 [==============================] - 6s 115us/step - loss: 0.
100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2427 - acc: 0.9161 - val_loss: 0.6675 - val_acc: 0.8040
# Epoch 92/100
# 50000/50000 [==============================] - 5s 104us/step - loss: 0.2406 - acc: 0.9181 - val_loss: 0.8421 - val_acc: 0.7607
# Epoch 93/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2403 - acc: 0.9176 - val_loss: 1.0563 - val_acc: 0.7802
# Epoch 94/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2420 - acc: 0.9181 - val_loss: 0.7611 - val_acc: 0.8025
# Epoch 95/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2377 - acc: 0.9170 - val_loss: 0.7139 - val_acc: 0.7959
# Epoch 96/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2322 - acc: 0.9201 - val_loss: 0.7159 - val_acc: 0.8065
# Epoch 97/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2423 - acc: 0.9165 - val_loss: 0.7970 - val_acc: 0.8017
# Epoch 98/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2322 - acc: 0.9203 - val_loss: 0.7414 - val_acc: 0.8109
# Epoch 99/100
# 50000/50000 [==============================] - 5s 102us/step - loss: 0.2390 - acc: 0.9190 - val_loss: 0.7352 - val_acc: 0.8024
# Epoch 100/100
# 50000/50000 [==============================] - 5s 103us/step - loss: 0.2377 - acc: 0.9188 - val_loss: 0.7044 - val_acc: 0.8109
# Test loss: 0.704415485906601
# Test accuracy: 0.8109

# %% [markdown]
# The computational time was around 500  secs for training with 100 epochs. compared to the previous implementation here and mainly since the epochs are more, the time is more.
#
# The accuracy also increased by around 5%, to 80%. So, with the tradeoff of computational complexity vs accuracy, I like this implentation 5 since 5% increase in accuracy is worth it even though the time is 500secs which is not that bad.

# %% [markdown]
# # Implementation 6:  Convolutional Neural Network with  Data Augmentation and additional parameters

# %%
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras.callbacks import LearningRateScheduler


def learnR_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
#z-score normalization
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
 
weight_decay = 1e-4
model = Sequential()

model.add(Conv2D(32, (3,3),padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3),padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))


model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))


model.add(Conv2D(128, (3,3),padding='same',  kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3),padding='same',  kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()
 
#data augmentation
datagener_train = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )

datagener_train.fit(x_train)

#training of data
batch_size = 64
epochs = 100 
opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.fit_generator(datagener_train.flow(x_train, y_train, batch_size=64),
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=epochs,
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(learnR_schedule)])

 
#Evaluation for Test data accuracy
scores = model.evaluate(x_test, y_test, batch_size=batch_size)
print('\nTest result: %.2f loss: %.2f' % (scores[1]*100,scores[0]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/100
# 781/781 [==============================] - 27s 35ms/step - loss: 1.9020 - acc: 0.4258 - val_loss: 1.3324 - val_acc: 0.5788
# Epoch 2/100
# 781/781 [==============================] - 26s 33ms/step - loss: 1.2794 - acc: 0.5909 - val_loss: 1.2298 - val_acc: 0.6395
# Epoch 3/100
# 781/781 [==============================] - 25s 32ms/step - loss: 1.0903 - acc: 0.6519 - val_loss: 1.0287 - val_acc: 0.6895
# Epoch 4/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.9785 - acc: 0.6908 - val_loss: 0.9426 - val_acc: 0.7086
# Epoch 5/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.9194 - acc: 0.7156 - val_loss: 0.8970 - val_acc: 0.7352
# Epoch 6/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.8759 - acc: 0.7305 - val_loss: 0.7420 - val_acc: 0.7889
# Epoch 7/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.8373 - acc: 0.7463 - val_loss: 0.7913 - val_acc: 0.7762
# Epoch 8/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.8088 - acc: 0.7575 - val_loss: 0.7186 - val_acc: 0.7908
# Epoch 9/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7855 - acc: 0.7677 - val_loss: 0.7134 - val_acc: 0.7986
# Epoch 10/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7714 - acc: 0.7744 - val_loss: 0.7202 - val_acc: 0.8021
# Epoch 11/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.7553 - acc: 0.7793 - val_loss: 0.7304 - val_acc: 0.7972
# Epoch 12/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.7389 - acc: 0.7887 - val_loss: 0.7925 - val_acc: 0.7798
# Epoch 13/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.
100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4922 - acc: 0.8759 - val_loss: 0.4952 - val_acc: 0.8812
# Epoch 83/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4905 - acc: 0.8761 - val_loss: 0.4984 - val_acc: 0.8790
# Epoch 84/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4852 - acc: 0.8794 - val_loss: 0.4993 - val_acc: 0.8800
# Epoch 85/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4786 - acc: 0.8793 - val_loss: 0.4812 - val_acc: 0.8856
# Epoch 86/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4813 - acc: 0.8778 - val_loss: 0.5192 - val_acc: 0.8735
# Epoch 87/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4772 - acc: 0.8782 - val_loss: 0.5272 - val_acc: 0.8707
# Epoch 88/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4766 - acc: 0.8782 - val_loss: 0.5030 - val_acc: 0.8781
# Epoch 89/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4739 - acc: 0.8794 - val_loss: 0.5235 - val_acc: 0.8677
# Epoch 90/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4702 - acc: 0.8790 - val_loss: 0.5382 - val_acc: 0.8693
# Epoch 91/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4710 - acc: 0.8791 - val_loss: 0.5005 - val_acc: 0.8732
# Epoch 92/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.4681 - acc: 0.8803 - val_loss: 0.5028 - val_acc: 0.8769
# Epoch 93/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4706 - acc: 0.8785 - val_loss: 0.5048 - val_acc: 0.8770
# Epoch 94/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4611 - acc: 0.8816 - val_loss: 0.4781 - val_acc: 0.8826
# Epoch 95/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4592 - acc: 0.8832 - val_loss: 0.5036 - val_acc: 0.8744
# Epoch 96/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4650 - acc: 0.8803 - val_loss: 0.5184 - val_acc: 0.8730
# Epoch 97/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4627 - acc: 0.8804 - val_loss: 0.5134 - val_acc: 0.8720
# Epoch 98/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4592 - acc: 0.8815 - val_loss: 0.5247 - val_acc: 0.8684
# Epoch 99/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.4600 - acc: 0.8793 - val_loss: 0.5188 - val_acc: 0.8731
# Epoch 100/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4559 - acc: 0.8835 - val_loss: 0.5536 - val_acc: 0.8628
# 10000/10000 [==============================] - 1s 81us/step
#
# Test result: 86.28 loss: 0.55

# %% [markdown]
# ### Test accuracy of around  88% was achieved with CNN model for image classification

# %% [markdown]
# The computational time was around 2700 secs compared to previous implementation of 500  secs for training with 100 epochs. The real time data augmentation increased the complexity of computation and increased the compuational time.
#
# Given the tradeoff of time betwen the two implementations, since the accuracy increased by 8% which is not negligible to not accept.
#
# I like this implentation 6 since the  increase in accuracy is worth it even though the time is 5 times more.

# %% [markdown]
# Next, tried to see below,  if using a imagedatagenerator for test data helps, since in evaluation we are not comparing to the augmented test data. So, generated test_generator and used for model.evaluate_generator and validation tests too..
#
# But the same accuracy observed and if not little better. So as a concusion, the best implemenation is Implementation 6 above which is the best sofar.

# %%
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras.callbacks import LearningRateScheduler


def learnR_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
#z-score normalization
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
 
weight_decay = 1e-4
model = Sequential()

model.add(Conv2D(32, (3,3),padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3),padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))


model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))


model.add(Conv2D(128, (3,3),padding='same',  kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3),padding='same',  kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()

batch_size = 64
epochs = 100 
#data augmentation
train_generator = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
test_generator = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
train_generator.fit(x_train)
test_generator.fit(x_test)

#training of data
opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
model.fit_generator(train_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=epochs,
                    verbose=1,validation_data=test_generator.flow(x_test, y_test), validation_steps=x_test.shape[0] // batch_size,
                    callbacks=[LearningRateScheduler(learnR_schedule)])

 
#Evaluation for Test data accuracy
scores = model.evaluate_generator(test_generator.flow(x_test, y_test), steps=x_test.shape[0] // batch_size)
print('\nTest result: %.2f loss: %.2f' % (scores[1]*100,scores[0]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation